# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# *************************************************************************************************

# %% [markdown]
# **Zomato Data Set EDA**

# %% [markdown]
# **Importing the Header Files**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# **Importing the Dataset**

# %%
dataset = pd.read_csv('F://Data_Set/zomato.csv',encoding='latin1')

# %%
dataset.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dataset.shape
# Out:
# (9551, 21)

# %%
print("Total Rows in the Dataset  = ",len(dataset))
# Out:
# Total Rows in the Dataset  =  9551

# %%
print("Total columns in the Dataset = ",len(dataset.columns))
# Out:
# Total columns in the Dataset =  21

# %%
print("Columns in the Dataset are = ",dataset.columns)
# Out:
# Columns in the Dataset are =  Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# Dataset information/Data Type of columns of Dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# Description of dataset

# %%
dataset.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### Basic Steps of the Data Analyst
#
# **1] Finding the Null Values in thee dataset**
#
# **2] Explore about the numerical feature**
#
# **3] Explore about categorical feature**
#
# **4] Findinging relationshiop between feature**

# %% [markdown]
# To check any null value present in the dataset or not

# %%
dataset.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Find missing value column with the help of code

# %%
[feature for feature in dataset.columns if dataset[feature].isnull().sum()>0]
# Out:
# ['Cuisines']

# %% [markdown]
# To Display the missing values of features with graph

# %%
msno.bar(dataset)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We have 9 missing values in the Cuisines

# %% [markdown]
# Matrix Display of Missing value

# %%
msno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Display the missing values by using the heatmap

# %%
plt.figure(figsize= (8,8))
sns.heatmap(dataset.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Check any Duplicate Record is present in the dataset or not

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# To check total no of duplicate present in the dataset

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Read New dataset

# %% [markdown]
# Country-Code.xlsx is excel file hence we use pd.read_excel

# %%
df_country_code = pd.read_excel('f://Data_Set/Country-Code.xlsx')

# %%
df_country_code.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia
